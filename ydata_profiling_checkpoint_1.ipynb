# %% [markdown]
# <a href="https://colab.research.google.com/github/Ikwuegbu/Git-Checkpoint/blob/main/ydata_profiling_checkpoint_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Data exploration with Pandas
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/EDUCATION_ATTAINMENT.csv')

# Display general information about the dataset
print("General information about the dataset:")
df.info()

# Run descriptive analysis using the 'describe' function
print("\nDescriptive statistics of the dataset:")
print(df.describe())
# Out:
# General information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ages[15-49]_All_grade1     626 non-null    float64
#  1   Ages[15-49]_All_grade2     626 non-null    float64
#  2   Ages[15-49]_All_grade3     626 non-null    float64
#  3   Ages[20-29]_All_grade1     626 non-null    float64
#  4   Ages[20-29]_All_grade2     626 non-null    float64
#  5   Ages[20-29]_All_grade3     626 non-null    float64
#  6   Ages[30-39]_All_grade1     625 non-null    float64
#  7   Ages[30-39]_All_grade2     625 non-null    float64
#  8   Ages[30-39]_All_grade3     625 non-null    float64
#  9   Ages[40-49]_All_grade1     625 non-null    float64
#  10  Ages[40-49]_All_grade2     625 non-null    float64
#  11  Ages[40-49]_All_grade3     625 non-null    float64
# ...

# %%
pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 35.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 82.2 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=a3b47b057aa1e98af36003b180b59ef1b542bc943eb30b2cf64791e8255bc845
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
# Step 2: Data exploration with ydata-profiling
from ydata_profiling import ProfileReport

# Generate a profiling report
profile = ProfileReport(df, title="Dataset Profiling Report", explorative=True)

# Save the report as an HTML file and display the report in the notebook
profile.to_file("dataset_profile_report.html")

# Display the profiling report (optional, depending on the environment you're using)
profile.to_notebook_iframe()

# Check for missing values in the dataset using ydata-profiling report
# This can be identified through the report itself, no need for extra code here.

# Examine correlations between different columns using the ydata report
# This can be found in the correlations section of the ydata-profiling report.

# Identify patterns or insights by reviewing the generated ydata-profiling report
# For example, looking at the distributions, outliers, skewness, and more.
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Buffered data was truncated after reaching the output size limit.
